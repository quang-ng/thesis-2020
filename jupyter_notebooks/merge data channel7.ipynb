# %%
import pandas as pd

# %%
channel_7_1 = pd.read_excel("./stress_and_CV_experiment_7_Channel_7.1.xlsx", sheet_name="Channel_7_1")
channel_7_2 = pd.read_excel("./stress_and_CV_experiment_7_Channel_7.2.xlsx", sheet_name="Channel_7_1")
channel_7_3 = pd.read_excel("./stress_and_CV_experiment_7_Channel_7.3.xlsx", sheet_name="Channel_7_1")
channel_7_4 = pd.read_excel("./stress_and_CV_experiment_7_Channel_7.4.xlsx", sheet_name="Channel_7_1")

# %%
channel_7 = pd.concat([channel_7_1, channel_7_2, channel_7_3, channel_7_4], ignore_index=True)

# %%
channel_7.head()
# Out:
#                 Date_Time  Test_Time(s)  Step_Time(s)  Step_Index  \
# 0 2018-09-14 16:39:49.863       60.0105       60.0104           1
# 1 2018-09-14 16:40:49.864      120.0118      120.0117           1
# 2 2018-09-14 16:41:49.853      180.0009      180.0008           1
# 3 2018-09-14 16:42:49.861      240.0089      240.0088           1
# 4 2018-09-14 16:43:49.860      300.0078      300.0077           1
#
#    Cycle_Index  Voltage(V)  Current(A)  Charge_Capacity(Ah)  \
# 0            1    3.530674    1.299788             0.021548
# 1            1    3.558775    1.299831             0.043207
# 2            1    3.570162    1.299841             0.064868
# 3            1    3.576921    1.299820             0.086534
# 4            1    3.583076    1.299814             0.108199
#
#    Discharge_Capacity(Ah)  Charge_Energy(Wh)  Discharge_Energy(Wh)  ACR(Ohm)  \
# 0            1.761754e-09           0.075472          5.921388e-09       NaN
# 1            1.761754e-09           0.152293          5.921388e-09       NaN
# 2            1.761754e-09           0.229519          5.921388e-09       NaN
# 3            1.761754e-09           0.306949          5.921388e-09       NaN
# 4            1.761754e-09           0.384509          5.921388e-09       NaN
#
#    Internal Resistance(Ohm)  dV/dt(V/s)  Aux_Temperature(℃)_1
# 0                       0.0    0.000741             24.395367
# 1                       0.0    0.000298             24.387411
# 2                       0.0    0.000166             24.498089
# 3                       0.0    0.000125             24.578352
# 4                       0.0    0.000127             24.493792

# %%
channel_7.to_csv("channel_7.csv", index=False)

# %%
asdf
